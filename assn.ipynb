# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import operator
import warnings; warnings.simplefilter('ignore')
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.model_selection import train_test_split
import sklearn

# %%
from sklearn.linear_model import LogisticRegression
clf = LogisticRegression()

# %%
df=pd.read_csv("iris_dataset.csv")
df.head()
# Out:
#      Name  Technical_trait  ...  Class  Criminal
# 0    Alok         0.632358  ...    1.7         0
# 1    Ravi         0.169630  ...    0.6        -1
# 2  Kalyan         0.844385  ...    2.1         1
# 3   Stuti         0.363624  ...    1.3         0
# 4  Pratik         0.218067  ...    1.1         0
#
# [5 rows x 9 columns]

# %%
final_x=df[['Technical_traits','Personal_traits','Social_characteristics']]
final_y=df[['Criminal']]

scaler = StandardScaler()
input_df = scaler.fit_transform(final_x)
#final_y['Criminal'].replace([-1], [2], inplace=True)
final_x
X_train, X_test, y_train, y_test = train_test_split(final_x,final_y,test_size=0.2, random_state=42,shuffle=False )

# %%
sns.pairplot(df, hue='Criminal', size=2.5)

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
pred=clf.predict(X_test)

# %%
sklearn.metrics.mean_absolute_error(y_test,pred)
# Out:
# 0.08333333333333333

# %%
print("Compare the person's characters with these given characters and enumerate how many technical traits does the subject have . ")
print("Sharp \nFocused \nWell trained \nStrategic Planner \nBully \nResourceful \nGoal-Oriented \nWellNetworked \nWell Organized \nSmart \nSkillful \nOppertunist\n")
print("How many of the characters does the person has \n")
z=1
a = input()
a=int(a)
if a>8:
  b=1
elif a>=5:
  b=0.6
elif a>2:
  b=0.3
else:
  b=0

    
b
# Out:
# Compare the person's characters with these given characters and enumerate how many technical traits does the subject have .
# Sharp
# Focused
# Well trained
# Strategic Planner
# Bully
# Resourceful
# Goal-Oriented
# WellNetworked
# Well Organized
# Smart
# Skillful
# Oppertunist
#
# How many of the characters does the person has
#
# 4
# 0.3

# %%
print("Compare the person's characters with these given characters and enumerate how many personal traits does the subject have . ")
print("Impatient \nDetermined \nInsensitive \nAggresive \nStrong Willed \nPassionate \nInsensitive \nChaotic state of mind  \nVengeful \nCoercive \nLoner \nImmoral")
print("How many of the characters does the person has \n")
z=1


a = input()
a=int(a)
if a>8:
  c=1
  z=2
elif a>=5:
  c=0.6
elif a>2:
  c=0.3
else:
  c=0
c
# Out:
# Compare the person's characters with these given characters and enumerate how many personal traits does the subject have .
# Impatient
# Determined
# Insensitive
# Aggresive
# Strong Willed
# Passionate
# Insensitive
# Chaotic state of mind
# Vengeful
# Coercive
# Loner
# Immoral
# How many of the characters does the person has
#
# 5
# 0.6

# %%
print("Compare the person's characters with these given characters and enumerate how many social characters does the subject have . ")
print("Anti establishment \nLack Social Skills \nLoner \nInferirority Complex \nLow SelfWorth \nMarginalized \nRadical \nMass Destruction  \nMisguided \nBrainWashed \nUnlawful \nRebellious")
print("How many of the characters does the person has \n")



a = input()
a=int(a)
if a>8:
  d=1
  z=2
elif a>=5:
  d=0.6
elif a>2:
  d=0.3
else:
  d=0
d
# Out:
# Compare the person's characters with these given characters and enumerate how many social characters does the subject have .
# Anti establishment
# Lack Social Skills
# Loner
# Inferirority Complex
# Low SelfWorth
# Marginalized
# Radical
# Mass Destruction
# Misguided
# BrainWashed
# Unlawful
# Rebellious
# How many of the characters does the person has
#
# 8
# 0.6

# %%
X_trai=pd.DataFrame({'Technical_traits':[1.1],'Personal_traits':[1.1],'Social_characteristics':[1.1]})
X_trai['Technical_traits'][0]=b
X_trai['Personal_traits'][0]=c
X_trai['Social_characteristics'][0]=d
X_trai
pred=clf.predict(X_trai)
know=pred[0]
all=clf.predict_proba(X_trai)
s=clf.predict_proba(X_trai)

if know == 1:
  print("He/she might be a cyber criminal according to our data")
  print('The value obtained was ',s[0][2],"which was the highest among other potentials" )

elif know==0:
  print("He/she isnt a cyber criminal but could be because he is in averge  of being so. Please take care of him/her")
  print('The value obtained was ',s[0][1],"which was the highest among other potentials" )
else:
  print("He/she is not a cyber criminal ")
  print('The value obtained was',s[0][0],"which was the highest among other potentials" )
# Out:
# He she isnt a cyber criminal but could be because he is in averge  of being so please take care of him/her
# The value obtained was  0.5929057942719662 which was the highest among other potentials

# %%
# Out:
# array([[0.40379515, 0.43604871, 0.16015615]])
